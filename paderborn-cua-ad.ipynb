# %% [markdown]
# ### Adversarial Discriminative Domain Adaptation

# %%
# import modules and libraries
import torch
import torch.nn as nn
from torch.optim import Adam
from torch.autograd import Variable

# functions to create datasets and models
from data.data import *
from models.models import *

# %%
# check if CUDA is available
train_on_gpu = torch.cuda.is_available()

if not train_on_gpu:
    print('CUDA is not available')
else:
    print('CUDA is available')
    device = torch.device('cuda')
# Out:
# CUDA is available

# %% [markdown]
# ### Parameters

# %%
"""Parameters for this experiment"""
# params for loading the data
path = 'data/Paderborn_FD/'
source_domain = 'a'
target_domains = ['b', 'c', 'd']

# params for configuring the model
input_dim = 1
hidden_dim = 256
output_dim = 3
drop_prob = 0.5

# params for training the model
epochs_pre = 50 # pre-training
epochs = 50

# optimizing the model
lr = 1e-4
d_lr = 1e-4
batch_size = 20
beta1 = 0.5
beta2 = 0.9

# %% [markdown]
# ### Data Loading

# %%
# source domain data for training, validating and testing
train_dataloader_src, val_dataloader_src, test_dataloader_src = generate_dataloaders(path, source_domain, batch_size)

# target domain data for validating and testing
train_dataloader_tgt, val_dataloader_tgt, test_dataloader_tgt = [], [], []
for target_domain in target_domains:
    train_dataloader_temp, val_dataloader_temp, test_dataloader_temp = generate_dataloaders(path, target_domain, batch_size)
    
    train_dataloader_tgt.append(train_dataloader_temp)
    val_dataloader_tgt.append(val_dataloader_temp)
    test_dataloader_tgt.append(test_dataloader_temp)

# %% [markdown]
# ### Model

# %%
encoder_src = Encoder_AMDA(
    input_dim=input_dim, # 1D input (sensor readings)
    hidden_dim=hidden_dim # hidden layers 64
)

classifier = Classifier_AMDA(
    hidden_dim=hidden_dim, # hidden layers 64
    output_dim=output_dim, # 3 classes (healthy, inner- and outer-bearing damages)
    dropout=drop_prob # dropout prob 0.5
)

encoder_tgt = Encoder_AMDA(
    input_dim=input_dim, # 1D input (sensor readings)
    hidden_dim=hidden_dim, # hidden layers 64
)

discriminator = Discriminator(
    hidden_dim=hidden_dim
)

if train_on_gpu:
    encoder_src = encoder_src.to(device)
    classifier = classifier.to(device)
    encoder_tgt = encoder_tgt.to(device)
    discriminator = discriminator.to(device)

# %% [markdown]
# #### Functions for training and testing the model

# %%
# functions for training source encoder and shared classifier
def train_src(encoder, classifier):
    """Train the source encoder and shared classifier on source domain"""
    encoder.train()
    classifier.train()

    criterion = nn.CrossEntropyLoss()
    optimizer = Adam(
        list(encoder.parameters()) + list(classifier.parameters()),
        lr=lr,
        betas=(beta1, beta2)
    )

    for epoch in range(epochs_pre):
        accuracies = []
        losses = []

        for batch_idx, (x_src, y_src) in enumerate(train_dataloader_src):
            if train_on_gpu:
                x_src, y_src = x_src.to(device), y_src.to(device)

            optimizer.zero_grad()

            e_src = encoder(x_src)
            pred_src = classifier(e_src)
            loss_src = criterion(pred_src, y_src)
            loss_src.backward()

            optimizer.step()

            losses.append(loss_src.detach().item()) # detach the loss from compute graph 
            accuracies.append(y_src.eq(pred_src.detach().argmax(dim=1)).float().mean())
        
        # print for each epoch
        print(f'Epoch: {epoch + 1} \n \t Train Loss:{torch.tensor(losses).mean():0.2f} \t Train Acc:{torch.tensor(accuracies).mean():0.2f}')

        # for each epoch, evaluate your model on the validation data
        val_loss, val_acc = evaluate_src(encoder, classifier, phase = 'Val')
        print(f'\t Val Loss:{val_loss:0.2f} \t\t Val Acc:{val_acc:0.2f}')

    return encoder, classifier

# testing model on source domain
def evaluate_src(encoder, classifier, phase='Val'): # phase can be validate or test
    """Evaluate the trained network on source domain"""
    encoder.eval()
    classifier.eval()

    criterion = nn.CrossEntropyLoss()
    
    losses = []
    accuracies = []
    dataloader = val_dataloader_src if phase == 'Val' else test_dataloader_src
    
    with torch.no_grad():
        for batch_idx, (x_src, y_src) in enumerate(dataloader):
            if train_on_gpu:
                x_src, y_src = x_src.to(device), y_src.to(device)

            e_src = encoder(x_src)
            pred_src = classifier(e_src)
            loss_src = criterion(pred_src, y_src)
            
            # append loss for each batch
            losses.append(loss_src.detach().item()) # detach the loss from compute graph 
            accuracies.append(y_src.eq(pred_src.detach().argmax(dim=1)).float().mean())
            
        mean_loss = torch.tensor(losses).mean()
        mean_acc = torch.tensor(accuracies).mean()
        return mean_loss, mean_acc

# %%
# Continuous Unsupervised Adaptation (CUA)
# functions for training target encoder
def train_tgt(encoder_src, encoder_tgt, classifier, discriminator, phase):
    """Train the target encoder on target domains with source encoder and test the network"""
    encoder_tgt.train()
    discriminator.train()
    classifier.eval()

    criterion = nn.CrossEntropyLoss()
    optimizer = Adam(
        encoder_tgt.parameters(),
        lr=lr,
        betas=(beta1, beta2)
    )
    d_optimizer = Adam(
        discriminator.parameters(),
        lr=d_lr,
        betas=(beta1, beta2)
    )

    for epoch in range(epochs):
        losses = []
        losses_d = []
        accuracies = []
        accuracies_d = []

        for batch_idx, ((x_src, y_src), (x_tgt, y_tgt)) in enumerate(zip(train_dataloader_src, train_dataloader_tgt[phase])):
            if(train_on_gpu):
                x_src, y_src = x_src.to(device), y_src.to(device)
                x_tgt, y_tgt = x_tgt.to(device), y_tgt.to(device)

            optimizer.zero_grad()
            d_optimizer.zero_grad()

            # part 1: sequential unsupervised adaptation
            # learn e_src and _tgt: source and target mapping represenations
            e_src = encoder_src(x_src)
            e_tgt = encoder_tgt(x_tgt)
            e_concat = torch.concat((e_src.detach(), e_tgt.detach()), 0)
            # minimize distance between source and target empirical mapping distribution using adversarial discriminator
            d_concat = discriminator(e_concat)

            label_src = Variable(torch.ones(e_src.size(0)).long()).to(device)
            label_tgt = Variable(torch.zeros(e_tgt.size(0)).long()).to(device)
            label_concat = torch.cat((label_src, label_tgt), 0)

            loss_d = criterion(d_concat, label_concat)
            loss_d.backward()
            d_optimizer.step()

            e_tgt = encoder_tgt(x_tgt)
            pred_tgt = classifier(e_tgt)
            d_tgt = discriminator(e_tgt)
            label_tgt = Variable(torch.ones(e_tgt.size(0)).long()).to(device)
            loss = criterion(d_tgt, label_tgt)

            loss.backward()
            optimizer.step()
            
            # training (with replay) losses and accuracies
            losses.append(loss.detach().item()) # detach the loss from compute graph
            losses_d.append(loss_d.detach().item())
            accuracies.append(y_tgt.eq(pred_tgt.detach().argmax(dim=1)).float().mean())
            accuracies_d.append(torch.squeeze(d_concat.max(1)[1]).eq(label_concat.detach()).float().mean())
        
        # print for each epoch
        print(f'Epoch: {epoch + 1} \n \t Train (with Adv) Loss:{torch.tensor(losses).mean():0.2f} \t Train Acc:{torch.tensor(accuracies).mean():0.2f}')
        print(f'\t Discriminator Loss:{torch.tensor(losses_d).mean():0.2f} \t Discriminator Acc:{torch.tensor(accuracies_d).mean():0.2f} ')

        # for each epoch, evaluate your model on the validation data
        val_loss, val_acc = evaluate_tgt(encoder_tgt, classifier, val_dataloader_tgt[phase])
        print(f'\t Val (with Target) Loss:{val_loss:0.2f} \t Val (with Target) Acc:{val_acc:0.2f}')

    return encoder_tgt
    
# testing model on target domains

def evaluate_tgt(encoder, classifier, dataloader):
    """Evaluate the network on current target domain"""
    encoder.eval()
    classifier.eval()

    criterion = nn.CrossEntropyLoss()
    
    losses = []
    accuracies = []
    
    with torch.no_grad():
        for batch_idx, (x, y) in enumerate(dataloader): # target dataloader
            if(train_on_gpu):
                x, y = x.to(device), y.to(device)

            pred_tgt = classifier(encoder(x))
            loss_tgt = criterion(pred_tgt, y)
            
            # append loss for each batch
            losses.append(loss_tgt.detach().item()) # detach the loss from compute graph 
            accuracies.append(y.eq(pred_tgt.detach().argmax(dim=1)).float().mean())
            
        mean_loss = torch.tensor(losses).mean()
        mean_acc = torch.tensor(accuracies).mean()
        return mean_loss, mean_acc

# %% [markdown]
# ### Pre-training

# %%
# pre-training
encoder_src, classifier = train_src(encoder_src, classifier)
# Out:
# Epoch: 1
#  	 Train Loss:0.74 	 Train Acc:0.65
# 	 Val Loss:0.46 		 Val Acc:0.80
# Epoch: 2
#  	 Train Loss:0.43 	 Train Acc:0.80
# 	 Val Loss:0.41 		 Val Acc:0.81
# Epoch: 3
#  	 Train Loss:0.37 	 Train Acc:0.81
# 	 Val Loss:0.32 		 Val Acc:0.84
# Epoch: 4
#  	 Train Loss:0.26 	 Train Acc:0.88
# 	 Val Loss:0.26 		 Val Acc:0.85
# Epoch: 5
#  	 Train Loss:0.19 	 Train Acc:0.92
# 	 Val Loss:0.23 		 Val Acc:0.87
# Epoch: 6
#  	 Train Loss:0.16 	 Train Acc:0.93
# 	 Val Loss:0.19 		 Val Acc:0.90
# Epoch: 7
#  	 Train Loss:0.13 	 Train Acc:0.95
# 	 Val Loss:0.17 		 Val Acc:0.92
# Epoch: 8
#  	 Train Loss:0.11 	 Train Acc:0.96
# 	 Val Loss:0.14 		 Val Acc:0.93
# Epoch: 9
#  	 Train Loss:0.09 	 Train Acc:0.97
# 	 Val Loss:0.11 		 Val Acc:0.95
# Epoch: 10
#  	 Train Loss:0.08 	 Train Acc:0.97
# 	 Val Loss:0.08 		 Val Acc:0.97
# Epoch: 11
#  	 Train Loss:0.07 	 Train Acc:0.98
# 	 Val Loss:0.06 		 Val Acc:0.98
# Epoch: 12
#  	 Train Loss:0.06 	 Train Acc:0.98
# 	 Val Loss:0.05 		 Val Acc:0.98
# Epoch: 13
#  	 Train Loss:0.05 	 Train Acc:0.98
# 	 Val Loss:0.04 		 Val Acc:0.99
# Epoch: 14
#  	 Train Loss:0.04 	 Train Acc:0.98
# 	 Val Loss:0.03 		 Val Acc:0.99
# Epoch: 15
#  	 Train Loss:0.04 	 Train Acc:0.98
# 	 Val Loss:0.03 		 Val Acc:0.99
# Epoch: 16
#  	 Train Loss:0.04 	 Train Acc:0.99
# 	 Val Loss:0.02 		 Val Acc:0.99
# Epoch: 17
#  	 Train Loss:0.03 	 Train Acc:0.99
# 	 Val Loss:0.02 		 Val Acc:0.99
# Epoch: 18
#  	 Train Loss:0.03 	 Train Acc:0.99
# 	 Val Loss:0.02 		 Val Acc:0.99
# Epoch: 19
#  	 Train Loss:0.03 	 Train Acc:0.99
# 	 Val Loss:0.02 		 Val Acc:0.99
# Epoch: 20
#  	 Train Loss:0.03 	 Train Acc:0.99
# 	 Val Loss:0.02 		 Val Acc:0.99
# Epoch: 21
#  	 Train Loss:0.02 	 Train Acc:0.99
# 	 Val Loss:0.02 		 Val Acc:1.00
# Epoch: 22
#  	 Train Loss:0.02 	 Train Acc:0.99
# 	 Val Loss:0.02 		 Val Acc:0.99
# Epoch: 23
#  	 Train Loss:0.02 	 Train Acc:0.99
# 	 Val Loss:0.02 		 Val Acc:1.00
# Epoch: 24
#  	 Train Loss:0.02 	 Train Acc:0.99
# 	 Val Loss:0.02 		 Val Acc:1.00
# Epoch: 25
#  	 Train Loss:0.02 	 Train Acc:0.99
# 	 Val Loss:0.02 		 Val Acc:1.00
# Epoch: 26
#  	 Train Loss:0.02 	 Train Acc:0.99
# 	 Val Loss:0.02 		 Val Acc:1.00
# Epoch: 27
#  	 Train Loss:0.02 	 Train Acc:0.99
# 	 Val Loss:0.02 		 Val Acc:1.00
# Epoch: 28
#  	 Train Loss:0.01 	 Train Acc:1.00
# 	 Val Loss:0.01 		 Val Acc:1.00
# Epoch: 29
#  	 Train Loss:0.01 	 Train Acc:1.00
# 	 Val Loss:0.01 		 Val Acc:1.00
# Epoch: 30
#  	 Train Loss:0.01 	 Train Acc:1.00
# 	 Val Loss:0.01 		 Val Acc:1.00
# Epoch: 31
#  	 Train Loss:0.01 	 Train Acc:1.00
# 	 Val Loss:0.01 		 Val Acc:1.00
# Epoch: 32
#  	 Train Loss:0.01 	 Train Acc:1.00
# 	 Val Loss:0.01 		 Val Acc:1.00
# Epoch: 33
#  	 Train Loss:0.01 	 Train Acc:1.00
# 	 Val Loss:0.01 		 Val Acc:1.00
# Epoch: 34
#  	 Train Loss:0.01 	 Train Acc:1.00
# 	 Val Loss:0.01 		 Val Acc:1.00
# Epoch: 35
#  	 Train Loss:0.01 	 Train Acc:1.00
# 	 Val Loss:0.01 		 Val Acc:1.00
# Epoch: 36
#  	 Train Loss:0.01 	 Train Acc:1.00
# 	 Val Loss:0.01 		 Val Acc:1.00
# Epoch: 37
#  	 Train Loss:0.01 	 Train Acc:1.00
# 	 Val Loss:0.01 		 Val Acc:1.00
# Epoch: 38
#  	 Train Loss:0.01 	 Train Acc:1.00
# 	 Val Loss:0.01 		 Val Acc:1.00
# Epoch: 39
#  	 Train Loss:0.01 	 Train Acc:1.00
# 	 Val Loss:0.01 		 Val Acc:1.00
# Epoch: 40
#  	 Train Loss:0.01 	 Train Acc:1.00
# 	 Val Loss:0.02 		 Val Acc:0.99
# Epoch: 41
#  	 Train Loss:0.01 	 Train Acc:1.00
# 	 Val Loss:0.02 		 Val Acc:0.99
# Epoch: 42
#  	 Train Loss:0.01 	 Train Acc:1.00
# 	 Val Loss:0.02 		 Val Acc:0.99
# Epoch: 43
#  	 Train Loss:0.01 	 Train Acc:1.00
# 	 Val Loss:0.02 		 Val Acc:0.99
# Epoch: 44
#  	 Train Loss:0.01 	 Train Acc:1.00
# 	 Val Loss:0.02 		 Val Acc:0.99
# Epoch: 45
#  	 Train Loss:0.01 	 Train Acc:1.00
# 	 Val Loss:0.02 		 Val Acc:0.99
# Epoch: 46
#  	 Train Loss:0.01 	 Train Acc:1.00
# 	 Val Loss:0.02 		 Val Acc:0.99
# Epoch: 47
#  	 Train Loss:0.01 	 Train Acc:1.00
# 	 Val Loss:0.01 		 Val Acc:1.00
# Epoch: 48
#  	 Train Loss:0.00 	 Train Acc:1.00
# 	 Val Loss:0.01 		 Val Acc:1.00
# Epoch: 49
#  	 Train Loss:0.01 	 Train Acc:1.00
# 	 Val Loss:0.01 		 Val Acc:1.00
# Epoch: 50
#  	 Train Loss:0.00 	 Train Acc:1.00
# 	 Val Loss:0.01 		 Val Acc:1.00

# %%
encoder_tgt.load_state_dict(encoder_src.state_dict())

# adaptation
for phase in range(len(target_domains)):
    if(phase == 0): # Domain A to B
        print(f'\nPhase {phase + 1} (Domain {source_domain} to Domain {target_domains[phase]})')
    else: # Domain B to C, and Domain C to D
        print(f'\nPhase {phase + 1} (Domain {target_domains[phase - 1]} to Domain {target_domains[phase]})')
    
    encoder_tgt = train_tgt(encoder_src, encoder_tgt, classifier, discriminator, phase)
    
    print('\nTesting Accuracy on Previously Seen and Current Domains:')
    print(f'Source Domain {source_domain}:')
    src_test_loss, src_test_acc = evaluate_src(encoder_tgt, classifier, phase='Test')
    print(f'\t Test (with Source) Loss:{src_test_loss:0.2f} \t Test (with Source) Acc:{src_test_acc:0.2f}') 
    for p in range(phase + 1):
        print(f'Target Domain {target_domains[p]}:')
        tgt_test_loss, tgt_test_acc = evaluate_tgt(encoder_tgt, classifier, test_dataloader_tgt[phase])
        print(f'\t Test (with Target) Loss:{tgt_test_loss:0.2f} \t Test (with Target) Acc:{tgt_test_acc:0.2f}')
# Out:
# Phase 1 (Domain a to Domain b)
# Epoch: 1
#  	 Train (with Adv) Loss:0.78 	 Train Acc:0.86
# 	 Discriminator Loss:0.69 	 Discriminator Acc:0.55
# 	 Val (with Target) Loss:1.23 	 Val (with Target) Acc:0.91
# Epoch: 2
#  	 Train (with Adv) Loss:0.75 	 Train Acc:0.92
# 	 Discriminator Loss:0.68 	 Discriminator Acc:0.55
# 	 Val (with Target) Loss:1.55 	 Val (with Target) Acc:0.92
# Epoch: 3
#  	 Train (with Adv) Loss:0.77 	 Train Acc:0.93
# 	 Discriminator Loss:0.67 	 Discriminator Acc:0.58
# 	 Val (with Target) Loss:2.02 	 Val (with Target) Acc:0.91
# Epoch: 4
#  	 Train (with Adv) Loss:0.78 	 Train Acc:0.93
# 	 Discriminator Loss:0.66 	 Discriminator Acc:0.59
# 	 Val (with Target) Loss:1.44 	 Val (with Target) Acc:0.93
# Epoch: 5
#  	 Train (with Adv) Loss:0.80 	 Train Acc:0.94
# 	 Discriminator Loss:0.66 	 Discriminator Acc:0.59
# 	 Val (with Target) Loss:1.03 	 Val (with Target) Acc:0.94
# Epoch: 6
#  	 Train (with Adv) Loss:0.82 	 Train Acc:0.94
# 	 Discriminator Loss:0.65 	 Discriminator Acc:0.60
# 	 Val (with Target) Loss:0.97 	 Val (with Target) Acc:0.94
# Epoch: 7
#  	 Train (with Adv) Loss:0.83 	 Train Acc:0.94
# 	 Discriminator Loss:0.65 	 Discriminator Acc:0.59
# 	 Val (with Target) Loss:0.89 	 Val (with Target) Acc:0.93
# Epoch: 8
#  	 Train (with Adv) Loss:0.85 	 Train Acc:0.94
# 	 Discriminator Loss:0.65 	 Discriminator Acc:0.59
# 	 Val (with Target) Loss:0.91 	 Val (with Target) Acc:0.94
# Epoch: 9
#  	 Train (with Adv) Loss:0.85 	 Train Acc:0.95
# 	 Discriminator Loss:0.65 	 Discriminator Acc:0.59
# 	 Val (with Target) Loss:0.95 	 Val (with Target) Acc:0.95
# Epoch: 10
#  	 Train (with Adv) Loss:0.86 	 Train Acc:0.95
# 	 Discriminator Loss:0.65 	 Discriminator Acc:0.59
# 	 Val (with Target) Loss:1.01 	 Val (with Target) Acc:0.94
# Epoch: 11
#  	 Train (with Adv) Loss:0.86 	 Train Acc:0.95
# 	 Discriminator Loss:0.65 	 Discriminator Acc:0.59
# 	 Val (with Target) Loss:0.99 	 Val (with Target) Acc:0.95
# Epoch: 12
#  	 Train (with Adv) Loss:0.86 	 Train Acc:0.95
# 	 Discriminator Loss:0.66 	 Discriminator Acc:0.59
# 	 Val (with Target) Loss:0.76 	 Val (with Target) Acc:0.95
# Epoch: 13
#  	 Train (with Adv) Loss:0.86 	 Train Acc:0.96
# 	 Discriminator Loss:0.66 	 Discriminator Acc:0.59
# 	 Val (with Target) Loss:0.73 	 Val (with Target) Acc:0.93
# Epoch: 14
#  	 Train (with Adv) Loss:0.85 	 Train Acc:0.96
# 	 Discriminator Loss:0.66 	 Discriminator Acc:0.59
# 	 Val (with Target) Loss:0.66 	 Val (with Target) Acc:0.94
# Epoch: 15
#  	 Train (with Adv) Loss:0.86 	 Train Acc:0.96
# 	 Discriminator Loss:0.66 	 Discriminator Acc:0.58
# 	 Val (with Target) Loss:0.62 	 Val (with Target) Acc:0.94
# Epoch: 16
#  	 Train (with Adv) Loss:0.86 	 Train Acc:0.96
# 	 Discriminator Loss:0.65 	 Discriminator Acc:0.59
# 	 Val (with Target) Loss:0.74 	 Val (with Target) Acc:0.92
# Epoch: 17
#  	 Train (with Adv) Loss:0.86 	 Train Acc:0.95
# 	 Discriminator Loss:0.66 	 Discriminator Acc:0.59
# 	 Val (with Target) Loss:0.64 	 Val (with Target) Acc:0.93
# Epoch: 18
#  	 Train (with Adv) Loss:0.86 	 Train Acc:0.95
# 	 Discriminator Loss:0.66 	 Discriminator Acc:0.58
# 	 Val (with Target) Loss:0.57 	 Val (with Target) Acc:0.94
# Epoch: 19
#  	 Train (with Adv) Loss:0.85 	 Train Acc:0.96
# 	 Discriminator Loss:0.67 	 Discriminator Acc:0.57
# 	 Val (with Target) Loss:0.61 	 Val (with Target) Acc:0.94
# Epoch: 20
#  	 Train (with Adv) Loss:0.85 	 Train Acc:0.96
# 	 Discriminator Loss:0.67 	 Discriminator Acc:0.57
# 	 Val (with Target) Loss:0.60 	 Val (with Target) Acc:0.96
# Epoch: 21
#  	 Train (with Adv) Loss:0.84 	 Train Acc:0.96
# 	 Discriminator Loss:0.67 	 Discriminator Acc:0.56
# 	 Val (with Target) Loss:0.47 	 Val (with Target) Acc:0.96
# Epoch: 22
#  	 Train (with Adv) Loss:0.84 	 Train Acc:0.96
# 	 Discriminator Loss:0.67 	 Discriminator Acc:0.56
# 	 Val (with Target) Loss:0.62 	 Val (with Target) Acc:0.93
# Epoch: 23
#  	 Train (with Adv) Loss:0.83 	 Train Acc:0.96
# 	 Discriminator Loss:0.67 	 Discriminator Acc:0.57
# 	 Val (with Target) Loss:0.54 	 Val (with Target) Acc:0.95
# Epoch: 24
#  	 Train (with Adv) Loss:0.83 	 Train Acc:0.96
# 	 Discriminator Loss:0.67 	 Discriminator Acc:0.56
# 	 Val (with Target) Loss:0.53 	 Val (with Target) Acc:0.95
# Epoch: 25
#  	 Train (with Adv) Loss:0.84 	 Train Acc:0.96
# 	 Discriminator Loss:0.66 	 Discriminator Acc:0.57
# 	 Val (with Target) Loss:0.46 	 Val (with Target) Acc:0.95
# Epoch: 26
#  	 Train (with Adv) Loss:0.84 	 Train Acc:0.96
# 	 Discriminator Loss:0.67 	 Discriminator Acc:0.56
# 	 Val (with Target) Loss:0.45 	 Val (with Target) Acc:0.96
# Epoch: 27
#  	 Train (with Adv) Loss:0.83 	 Train Acc:0.96
# 	 Discriminator Loss:0.67 	 Discriminator Acc:0.56
# 	 Val (with Target) Loss:0.47 	 Val (with Target) Acc:0.94
# Epoch: 28
#  	 Train (with Adv) Loss:0.83 	 Train Acc:0.97
# 	 Discriminator Loss:0.67 	 Discriminator Acc:0.55
# 	 Val (with Target) Loss:0.47 	 Val (with Target) Acc:0.93
# Epoch: 29
#  	 Train (with Adv) Loss:0.82 	 Train Acc:0.96
# 	 Discriminator Loss:0.67 	 Discriminator Acc:0.56
# 	 Val (with Target) Loss:0.38 	 Val (with Target) Acc:0.96
# Epoch: 30
#  	 Train (with Adv) Loss:0.82 	 Train Acc:0.97
# 	 Discriminator Loss:0.67 	 Discriminator Acc:0.55
# 	 Val (with Target) Loss:0.46 	 Val (with Target) Acc:0.95
# Epoch: 31
#  	 Train (with Adv) Loss:0.82 	 Train Acc:0.97
# 	 Discriminator Loss:0.67 	 Discriminator Acc:0.55
# 	 Val (with Target) Loss:0.30 	 Val (with Target) Acc:0.96
# Epoch: 32
#  	 Train (with Adv) Loss:0.81 	 Train Acc:0.97
# 	 Discriminator Loss:0.67 	 Discriminator Acc:0.55
# 	 Val (with Target) Loss:0.45 	 Val (with Target) Acc:0.94
# Epoch: 33
#  	 Train (with Adv) Loss:0.81 	 Train Acc:0.97
# 	 Discriminator Loss:0.67 	 Discriminator Acc:0.56
# 	 Val (with Target) Loss:0.47 	 Val (with Target) Acc:0.96
# Epoch: 34
#  	 Train (with Adv) Loss:0.82 	 Train Acc:0.97
# 	 Discriminator Loss:0.67 	 Discriminator Acc:0.55
# 	 Val (with Target) Loss:0.42 	 Val (with Target) Acc:0.95
# Epoch: 35
#  	 Train (with Adv) Loss:0.81 	 Train Acc:0.97
# 	 Discriminator Loss:0.68 	 Discriminator Acc:0.55
# 	 Val (with Target) Loss:0.40 	 Val (with Target) Acc:0.95
# Epoch: 36
#  	 Train (with Adv) Loss:0.81 	 Train Acc:0.97
# 	 Discriminator Loss:0.67 	 Discriminator Acc:0.55
# 	 Val (with Target) Loss:0.36 	 Val (with Target) Acc:0.96
# Epoch: 37
#  	 Train (with Adv) Loss:0.81 	 Train Acc:0.97
# 	 Discriminator Loss:0.68 	 Discriminator Acc:0.55
# 	 Val (with Target) Loss:0.45 	 Val (with Target) Acc:0.96
# Epoch: 38
#  	 Train (with Adv) Loss:0.81 	 Train Acc:0.97
# 	 Discriminator Loss:0.68 	 Discriminator Acc:0.55
# 	 Val (with Target) Loss:0.40 	 Val (with Target) Acc:0.97
# Epoch: 39
#  	 Train (with Adv) Loss:0.81 	 Train Acc:0.97
# 	 Discriminator Loss:0.68 	 Discriminator Acc:0.54
# 	 Val (with Target) Loss:0.72 	 Val (with Target) Acc:0.95
# Epoch: 40
#  	 Train (with Adv) Loss:0.80 	 Train Acc:0.97
# 	 Discriminator Loss:0.68 	 Discriminator Acc:0.55
# 	 Val (with Target) Loss:0.43 	 Val (with Target) Acc:0.96
# Epoch: 41
#  	 Train (with Adv) Loss:0.79 	 Train Acc:0.97
# 	 Discriminator Loss:0.68 	 Discriminator Acc:0.54
# 	 Val (with Target) Loss:0.46 	 Val (with Target) Acc:0.97
# Epoch: 42
#  	 Train (with Adv) Loss:0.80 	 Train Acc:0.97
# 	 Discriminator Loss:0.68 	 Discriminator Acc:0.54
# 	 Val (with Target) Loss:0.50 	 Val (with Target) Acc:0.96
# Epoch: 43
#  	 Train (with Adv) Loss:0.79 	 Train Acc:0.97
# 	 Discriminator Loss:0.68 	 Discriminator Acc:0.55
# 	 Val (with Target) Loss:0.48 	 Val (with Target) Acc:0.96
# Epoch: 44
#  	 Train (with Adv) Loss:0.79 	 Train Acc:0.97
# 	 Discriminator Loss:0.68 	 Discriminator Acc:0.55
# 	 Val (with Target) Loss:0.37 	 Val (with Target) Acc:0.96
# Epoch: 45
#  	 Train (with Adv) Loss:0.79 	 Train Acc:0.97
# 	 Discriminator Loss:0.68 	 Discriminator Acc:0.54
# 	 Val (with Target) Loss:0.39 	 Val (with Target) Acc:0.95
# Epoch: 46
#  	 Train (with Adv) Loss:0.79 	 Train Acc:0.97
# 	 Discriminator Loss:0.68 	 Discriminator Acc:0.55
# 	 Val (with Target) Loss:0.51 	 Val (with Target) Acc:0.96
# Epoch: 47
#  	 Train (with Adv) Loss:0.78 	 Train Acc:0.97
# 	 Discriminator Loss:0.68 	 Discriminator Acc:0.55
# 	 Val (with Target) Loss:0.44 	 Val (with Target) Acc:0.96
# Epoch: 48
#  	 Train (with Adv) Loss:0.78 	 Train Acc:0.97
# 	 Discriminator Loss:0.68 	 Discriminator Acc:0.55
# 	 Val (with Target) Loss:0.55 	 Val (with Target) Acc:0.97
# Epoch: 49
#  	 Train (with Adv) Loss:0.79 	 Train Acc:0.97
# 	 Discriminator Loss:0.68 	 Discriminator Acc:0.55
# 	 Val (with Target) Loss:0.55 	 Val (with Target) Acc:0.97
# Epoch: 50
#  	 Train (with Adv) Loss:0.78 	 Train Acc:0.97
# 	 Discriminator Loss:0.68 	 Discriminator Acc:0.55
# 	 Val (with Target) Loss:0.60 	 Val (with Target) Acc:0.97
#
# Testing Accuracy on Previously Seen and Current Domains:
# Source Domain a:
# 	 Test (with Source) Loss:13.40 	 Test (with Source) Acc:0.39
# Target Domain b:
# 	 Test (with Target) Loss:0.53 	 Test (with Target) Acc:0.97
#
# Phase 2 (Domain b to Domain c)
# Epoch: 1
#  	 Train (with Adv) Loss:0.83 	 Train Acc:0.83
# 	 Discriminator Loss:0.65 	 Discriminator Acc:0.61
# 	 Val (with Target) Loss:1.95 	 Val (with Target) Acc:0.83
# Epoch: 2
#  	 Train (with Adv) Loss:0.85 	 Train Acc:0.82
# 	 Discriminator Loss:0.65 	 Discriminator Acc:0.60
# 	 Val (with Target) Loss:2.09 	 Val (with Target) Acc:0.81
# Epoch: 3
#  	 Train (with Adv) Loss:0.85 	 Train Acc:0.82
# 	 Discriminator Loss:0.65 	 Discriminator Acc:0.60
# 	 Val (with Target) Loss:2.29 	 Val (with Target) Acc:0.81
# Epoch: 4
#  	 Train (with Adv) Loss:0.85 	 Train Acc:0.82
# 	 Discriminator Loss:0.66 	 Discriminator Acc:0.60
# 	 Val (with Target) Loss:2.03 	 Val (with Target) Acc:0.81
# Epoch: 5
#  	 Train (with Adv) Loss:0.85 	 Train Acc:0.82
# 	 Discriminator Loss:0.66 	 Discriminator Acc:0.59
# 	 Val (with Target) Loss:2.23 	 Val (with Target) Acc:0.80
# Epoch: 6
#  	 Train (with Adv) Loss:0.84 	 Train Acc:0.81
# 	 Discriminator Loss:0.66 	 Discriminator Acc:0.58
# 	 Val (with Target) Loss:2.35 	 Val (with Target) Acc:0.80
# Epoch: 7
#  	 Train (with Adv) Loss:0.83 	 Train Acc:0.81
# 	 Discriminator Loss:0.67 	 Discriminator Acc:0.58
# 	 Val (with Target) Loss:2.36 	 Val (with Target) Acc:0.81
# Epoch: 8
#  	 Train (with Adv) Loss:0.84 	 Train Acc:0.81
# 	 Discriminator Loss:0.67 	 Discriminator Acc:0.58
# 	 Val (with Target) Loss:2.48 	 Val (with Target) Acc:0.81
# Epoch: 9
#  	 Train (with Adv) Loss:0.82 	 Train Acc:0.81
# 	 Discriminator Loss:0.67 	 Discriminator Acc:0.57
# 	 Val (with Target) Loss:2.66 	 Val (with Target) Acc:0.81
# Epoch: 10
#  	 Train (with Adv) Loss:0.82 	 Train Acc:0.81
# 	 Discriminator Loss:0.67 	 Discriminator Acc:0.57
# 	 Val (with Target) Loss:2.53 	 Val (with Target) Acc:0.81
# Epoch: 11
#  	 Train (with Adv) Loss:0.82 	 Train Acc:0.81
# 	 Discriminator Loss:0.68 	 Discriminator Acc:0.56
# 	 Val (with Target) Loss:2.57 	 Val (with Target) Acc:0.81
# Epoch: 12
#  	 Train (with Adv) Loss:0.81 	 Train Acc:0.81
# 	 Discriminator Loss:0.68 	 Discriminator Acc:0.56
# 	 Val (with Target) Loss:2.67 	 Val (with Target) Acc:0.81
# Epoch: 13
#  	 Train (with Adv) Loss:0.81 	 Train Acc:0.81
# 	 Discriminator Loss:0.68 	 Discriminator Acc:0.56
# 	 Val (with Target) Loss:2.72 	 Val (with Target) Acc:0.81
# Epoch: 14
#  	 Train (with Adv) Loss:0.81 	 Train Acc:0.81
# 	 Discriminator Loss:0.68 	 Discriminator Acc:0.56
# 	 Val (with Target) Loss:2.60 	 Val (with Target) Acc:0.81
# Epoch: 15
#  	 Train (with Adv) Loss:0.81 	 Train Acc:0.80
# 	 Discriminator Loss:0.68 	 Discriminator Acc:0.55
# 	 Val (with Target) Loss:2.57 	 Val (with Target) Acc:0.81
# Epoch: 16
#  	 Train (with Adv) Loss:0.81 	 Train Acc:0.81
# 	 Discriminator Loss:0.68 	 Discriminator Acc:0.55
# 	 Val (with Target) Loss:2.63 	 Val (with Target) Acc:0.81
# Epoch: 17
#  	 Train (with Adv) Loss:0.79 	 Train Acc:0.80
# 	 Discriminator Loss:0.68 	 Discriminator Acc:0.55
# 	 Val (with Target) Loss:2.67 	 Val (with Target) Acc:0.81
# Epoch: 18
#  	 Train (with Adv) Loss:0.80 	 Train Acc:0.80
# 	 Discriminator Loss:0.68 	 Discriminator Acc:0.55
# 	 Val (with Target) Loss:2.69 	 Val (with Target) Acc:0.81
# Epoch: 19
#  	 Train (with Adv) Loss:0.80 	 Train Acc:0.80
# 	 Discriminator Loss:0.68 	 Discriminator Acc:0.55
# 	 Val (with Target) Loss:2.79 	 Val (with Target) Acc:0.81
# Epoch: 20
#  	 Train (with Adv) Loss:0.80 	 Train Acc:0.80
# 	 Discriminator Loss:0.68 	 Discriminator Acc:0.55
# 	 Val (with Target) Loss:2.69 	 Val (with Target) Acc:0.81
# Epoch: 21
#  	 Train (with Adv) Loss:0.80 	 Train Acc:0.80
# 	 Discriminator Loss:0.68 	 Discriminator Acc:0.55
# 	 Val (with Target) Loss:2.77 	 Val (with Target) Acc:0.81
# Epoch: 22
#  	 Train (with Adv) Loss:0.79 	 Train Acc:0.80
# 	 Discriminator Loss:0.68 	 Discriminator Acc:0.54
# 	 Val (with Target) Loss:2.58 	 Val (with Target) Acc:0.80
# Epoch: 23
#  	 Train (with Adv) Loss:0.80 	 Train Acc:0.80
# 	 Discriminator Loss:0.68 	 Discriminator Acc:0.55
# 	 Val (with Target) Loss:2.78 	 Val (with Target) Acc:0.81
# Epoch: 24
#  	 Train (with Adv) Loss:0.80 	 Train Acc:0.80
# 	 Discriminator Loss:0.68 	 Discriminator Acc:0.55
# 	 Val (with Target) Loss:2.85 	 Val (with Target) Acc:0.81
# Epoch: 25
#  	 Train (with Adv) Loss:0.79 	 Train Acc:0.81
# 	 Discriminator Loss:0.69 	 Discriminator Acc:0.54
# 	 Val (with Target) Loss:2.73 	 Val (with Target) Acc:0.81
# Epoch: 26
#  	 Train (with Adv) Loss:0.80 	 Train Acc:0.80
# 	 Discriminator Loss:0.69 	 Discriminator Acc:0.54
# 	 Val (with Target) Loss:2.92 	 Val (with Target) Acc:0.81
# Epoch: 27
#  	 Train (with Adv) Loss:0.79 	 Train Acc:0.80
# 	 Discriminator Loss:0.69 	 Discriminator Acc:0.54
# 	 Val (with Target) Loss:2.80 	 Val (with Target) Acc:0.81
# Epoch: 28
#  	 Train (with Adv) Loss:0.78 	 Train Acc:0.81
# 	 Discriminator Loss:0.69 	 Discriminator Acc:0.54
# 	 Val (with Target) Loss:2.85 	 Val (with Target) Acc:0.81
# Epoch: 29
#  	 Train (with Adv) Loss:0.79 	 Train Acc:0.80
# 	 Discriminator Loss:0.69 	 Discriminator Acc:0.54
# 	 Val (with Target) Loss:2.68 	 Val (with Target) Acc:0.81
# Epoch: 30
#  	 Train (with Adv) Loss:0.79 	 Train Acc:0.81
# 	 Discriminator Loss:0.69 	 Discriminator Acc:0.54
# 	 Val (with Target) Loss:2.69 	 Val (with Target) Acc:0.81
# Epoch: 31
#  	 Train (with Adv) Loss:0.78 	 Train Acc:0.81
# 	 Discriminator Loss:0.69 	 Discriminator Acc:0.54
# 	 Val (with Target) Loss:2.71 	 Val (with Target) Acc:0.81
# Epoch: 32
#  	 Train (with Adv) Loss:0.79 	 Train Acc:0.81
# 	 Discriminator Loss:0.69 	 Discriminator Acc:0.54
# 	 Val (with Target) Loss:2.80 	 Val (with Target) Acc:0.81
# Epoch: 33
#  	 Train (with Adv) Loss:0.79 	 Train Acc:0.81
# 	 Discriminator Loss:0.68 	 Discriminator Acc:0.54
# 	 Val (with Target) Loss:2.92 	 Val (with Target) Acc:0.81
# Epoch: 34
#  	 Train (with Adv) Loss:0.79 	 Train Acc:0.80
# 	 Discriminator Loss:0.69 	 Discriminator Acc:0.54
# 	 Val (with Target) Loss:2.81 	 Val (with Target) Acc:0.81
# Epoch: 35
#  	 Train (with Adv) Loss:0.78 	 Train Acc:0.81
# 	 Discriminator Loss:0.69 	 Discriminator Acc:0.54
# 	 Val (with Target) Loss:2.78 	 Val (with Target) Acc:0.81
# Epoch: 36
#  	 Train (with Adv) Loss:0.78 	 Train Acc:0.81
# 	 Discriminator Loss:0.68 	 Discriminator Acc:0.54
# 	 Val (with Target) Loss:2.70 	 Val (with Target) Acc:0.81
# Epoch: 37
#  	 Train (with Adv) Loss:0.78 	 Train Acc:0.81
# 	 Discriminator Loss:0.69 	 Discriminator Acc:0.54
# 	 Val (with Target) Loss:2.70 	 Val (with Target) Acc:0.81
# Epoch: 38
#  	 Train (with Adv) Loss:0.78 	 Train Acc:0.81
# 	 Discriminator Loss:0.69 	 Discriminator Acc:0.54
# 	 Val (with Target) Loss:2.50 	 Val (with Target) Acc:0.81
# Epoch: 39
#  	 Train (with Adv) Loss:0.78 	 Train Acc:0.81
# 	 Discriminator Loss:0.69 	 Discriminator Acc:0.54
# 	 Val (with Target) Loss:2.74 	 Val (with Target) Acc:0.81
# Epoch: 40
#  	 Train (with Adv) Loss:0.79 	 Train Acc:0.81
# 	 Discriminator Loss:0.69 	 Discriminator Acc:0.54
# 	 Val (with Target) Loss:2.51 	 Val (with Target) Acc:0.81
# Epoch: 41
#  	 Train (with Adv) Loss:0.78 	 Train Acc:0.81
# 	 Discriminator Loss:0.69 	 Discriminator Acc:0.53
# 	 Val (with Target) Loss:2.71 	 Val (with Target) Acc:0.81
# Epoch: 42
#  	 Train (with Adv) Loss:0.78 	 Train Acc:0.81
# 	 Discriminator Loss:0.69 	 Discriminator Acc:0.54
# 	 Val (with Target) Loss:2.82 	 Val (with Target) Acc:0.81
# Epoch: 43
#  	 Train (with Adv) Loss:0.78 	 Train Acc:0.81
# 	 Discriminator Loss:0.69 	 Discriminator Acc:0.53
# 	 Val (with Target) Loss:2.80 	 Val (with Target) Acc:0.81
# Epoch: 44
#  	 Train (with Adv) Loss:0.77 	 Train Acc:0.81
# 	 Discriminator Loss:0.69 	 Discriminator Acc:0.53
# 	 Val (with Target) Loss:2.68 	 Val (with Target) Acc:0.82
# Epoch: 45
#  	 Train (with Adv) Loss:0.78 	 Train Acc:0.81
# 	 Discriminator Loss:0.69 	 Discriminator Acc:0.53
# 	 Val (with Target) Loss:2.79 	 Val (with Target) Acc:0.82
# Epoch: 46
#  	 Train (with Adv) Loss:0.78 	 Train Acc:0.81
# 	 Discriminator Loss:0.69 	 Discriminator Acc:0.54
# 	 Val (with Target) Loss:2.78 	 Val (with Target) Acc:0.81
# Epoch: 47
#  	 Train (with Adv) Loss:0.78 	 Train Acc:0.81
# 	 Discriminator Loss:0.69 	 Discriminator Acc:0.53
# 	 Val (with Target) Loss:2.68 	 Val (with Target) Acc:0.81
# Epoch: 48
#  	 Train (with Adv) Loss:0.78 	 Train Acc:0.81
# 	 Discriminator Loss:0.69 	 Discriminator Acc:0.54
# 	 Val (with Target) Loss:2.72 	 Val (with Target) Acc:0.81
# Epoch: 49
#  	 Train (with Adv) Loss:0.78 	 Train Acc:0.81
# 	 Discriminator Loss:0.69 	 Discriminator Acc:0.54
# 	 Val (with Target) Loss:2.83 	 Val (with Target) Acc:0.82
# Epoch: 50
#  	 Train (with Adv) Loss:0.77 	 Train Acc:0.81
# 	 Discriminator Loss:0.69 	 Discriminator Acc:0.54
# 	 Val (with Target) Loss:2.67 	 Val (with Target) Acc:0.81
#
# Testing Accuracy on Previously Seen and Current Domains:
# Source Domain a:
# 	 Test (with Source) Loss:13.61 	 Test (with Source) Acc:0.39
# Target Domain b:
# 	 Test (with Target) Loss:2.55 	 Test (with Target) Acc:0.81
# Target Domain c:
# 	 Test (with Target) Loss:2.55 	 Test (with Target) Acc:0.81
#
# Phase 3 (Domain c to Domain d)
# Epoch: 1
#  	 Train (with Adv) Loss:0.81 	 Train Acc:0.91
# 	 Discriminator Loss:0.67 	 Discriminator Acc:0.59
# 	 Val (with Target) Loss:1.45 	 Val (with Target) Acc:0.89
# Epoch: 2
#  	 Train (with Adv) Loss:0.81 	 Train Acc:0.91
# 	 Discriminator Loss:0.67 	 Discriminator Acc:0.59
# 	 Val (with Target) Loss:0.80 	 Val (with Target) Acc:0.91
# Epoch: 3
#  	 Train (with Adv) Loss:0.82 	 Train Acc:0.92
# 	 Discriminator Loss:0.67 	 Discriminator Acc:0.58
# 	 Val (with Target) Loss:1.08 	 Val (with Target) Acc:0.89
# Epoch: 4
#  	 Train (with Adv) Loss:0.80 	 Train Acc:0.94
# 	 Discriminator Loss:0.67 	 Discriminator Acc:0.56
# 	 Val (with Target) Loss:0.26 	 Val (with Target) Acc:0.95
# Epoch: 5
#  	 Train (with Adv) Loss:0.80 	 Train Acc:0.97
# 	 Discriminator Loss:0.68 	 Discriminator Acc:0.56
# 	 Val (with Target) Loss:0.13 	 Val (with Target) Acc:0.97
# Epoch: 6
#  	 Train (with Adv) Loss:0.80 	 Train Acc:0.98
# 	 Discriminator Loss:0.68 	 Discriminator Acc:0.55
# 	 Val (with Target) Loss:0.08 	 Val (with Target) Acc:0.99
# Epoch: 7
#  	 Train (with Adv) Loss:0.79 	 Train Acc:0.99
# 	 Discriminator Loss:0.69 	 Discriminator Acc:0.55
# 	 Val (with Target) Loss:0.09 	 Val (with Target) Acc:0.98
# Epoch: 8
#  	 Train (with Adv) Loss:0.79 	 Train Acc:0.99
# 	 Discriminator Loss:0.68 	 Discriminator Acc:0.55
# 	 Val (with Target) Loss:0.05 	 Val (with Target) Acc:0.99
# Epoch: 9
#  	 Train (with Adv) Loss:0.79 	 Train Acc:0.99
# 	 Discriminator Loss:0.68 	 Discriminator Acc:0.55
# 	 Val (with Target) Loss:0.06 	 Val (with Target) Acc:0.99
# Epoch: 10
#  	 Train (with Adv) Loss:0.79 	 Train Acc:0.99
# 	 Discriminator Loss:0.69 	 Discriminator Acc:0.55
# 	 Val (with Target) Loss:0.06 	 Val (with Target) Acc:0.99
# Epoch: 11
#  	 Train (with Adv) Loss:0.79 	 Train Acc:0.99
# 	 Discriminator Loss:0.69 	 Discriminator Acc:0.54
# 	 Val (with Target) Loss:0.05 	 Val (with Target) Acc:0.99
# Epoch: 12
#  	 Train (with Adv) Loss:0.79 	 Train Acc:0.99
# 	 Discriminator Loss:0.69 	 Discriminator Acc:0.54
# 	 Val (with Target) Loss:0.05 	 Val (with Target) Acc:0.99
# Epoch: 13
#  	 Train (with Adv) Loss:0.78 	 Train Acc:0.99
# 	 Discriminator Loss:0.68 	 Discriminator Acc:0.55
# 	 Val (with Target) Loss:0.09 	 Val (with Target) Acc:0.98
# Epoch: 14
#  	 Train (with Adv) Loss:0.78 	 Train Acc:0.99
# 	 Discriminator Loss:0.69 	 Discriminator Acc:0.55
# 	 Val (with Target) Loss:0.10 	 Val (with Target) Acc:0.98
# Epoch: 15
#  	 Train (with Adv) Loss:0.78 	 Train Acc:0.99
# 	 Discriminator Loss:0.68 	 Discriminator Acc:0.55
# 	 Val (with Target) Loss:0.11 	 Val (with Target) Acc:0.97
# Epoch: 16
#  	 Train (with Adv) Loss:0.79 	 Train Acc:0.99
# 	 Discriminator Loss:0.69 	 Discriminator Acc:0.55
# 	 Val (with Target) Loss:0.02 	 Val (with Target) Acc:1.00
# Epoch: 17
#  	 Train (with Adv) Loss:0.80 	 Train Acc:0.99
# 	 Discriminator Loss:0.68 	 Discriminator Acc:0.55
# 	 Val (with Target) Loss:0.08 	 Val (with Target) Acc:0.98
# Epoch: 18
#  	 Train (with Adv) Loss:0.79 	 Train Acc:0.99
# 	 Discriminator Loss:0.69 	 Discriminator Acc:0.55
# 	 Val (with Target) Loss:0.04 	 Val (with Target) Acc:0.99
# Epoch: 19
#  	 Train (with Adv) Loss:0.79 	 Train Acc:0.99
# 	 Discriminator Loss:0.68 	 Discriminator Acc:0.56
# 	 Val (with Target) Loss:0.04 	 Val (with Target) Acc:0.99
# Epoch: 20
#  	 Train (with Adv) Loss:0.79 	 Train Acc:0.99
# 	 Discriminator Loss:0.69 	 Discriminator Acc:0.54
# 	 Val (with Target) Loss:0.02 	 Val (with Target) Acc:1.00
# Epoch: 21
#  	 Train (with Adv) Loss:0.78 	 Train Acc:0.99
# 	 Discriminator Loss:0.69 	 Discriminator Acc:0.54
# 	 Val (with Target) Loss:0.27 	 Val (with Target) Acc:0.95
# Epoch: 22
#  	 Train (with Adv) Loss:0.78 	 Train Acc:0.99
# 	 Discriminator Loss:0.68 	 Discriminator Acc:0.55
# 	 Val (with Target) Loss:0.02 	 Val (with Target) Acc:0.99
# Epoch: 23
#  	 Train (with Adv) Loss:0.78 	 Train Acc:0.99
# 	 Discriminator Loss:0.69 	 Discriminator Acc:0.55
# 	 Val (with Target) Loss:0.08 	 Val (with Target) Acc:0.98
# Epoch: 24
#  	 Train (with Adv) Loss:0.78 	 Train Acc:0.99
# 	 Discriminator Loss:0.68 	 Discriminator Acc:0.55
# 	 Val (with Target) Loss:0.04 	 Val (with Target) Acc:0.99
# Epoch: 25
#  	 Train (with Adv) Loss:0.78 	 Train Acc:0.99
# 	 Discriminator Loss:0.69 	 Discriminator Acc:0.54
# 	 Val (with Target) Loss:0.02 	 Val (with Target) Acc:1.00
# Epoch: 26
#  	 Train (with Adv) Loss:0.78 	 Train Acc:0.99
# 	 Discriminator Loss:0.69 	 Discriminator Acc:0.53
# 	 Val (with Target) Loss:0.06 	 Val (with Target) Acc:0.98
# Epoch: 27
#  	 Train (with Adv) Loss:0.78 	 Train Acc:0.99
# 	 Discriminator Loss:0.69 	 Discriminator Acc:0.54
# 	 Val (with Target) Loss:0.02 	 Val (with Target) Acc:0.99
# Epoch: 28
#  	 Train (with Adv) Loss:0.77 	 Train Acc:0.99
# 	 Discriminator Loss:0.69 	 Discriminator Acc:0.54
# 	 Val (with Target) Loss:0.11 	 Val (with Target) Acc:0.97
# Epoch: 29
#  	 Train (with Adv) Loss:0.77 	 Train Acc:0.99
# 	 Discriminator Loss:0.69 	 Discriminator Acc:0.53
# 	 Val (with Target) Loss:0.03 	 Val (with Target) Acc:0.99
# Epoch: 30
#  	 Train (with Adv) Loss:0.79 	 Train Acc:0.99
# 	 Discriminator Loss:0.69 	 Discriminator Acc:0.54
# 	 Val (with Target) Loss:0.04 	 Val (with Target) Acc:0.99
# Epoch: 31
#  	 Train (with Adv) Loss:0.77 	 Train Acc:0.99
# 	 Discriminator Loss:0.69 	 Discriminator Acc:0.54
# 	 Val (with Target) Loss:0.02 	 Val (with Target) Acc:1.00
# Epoch: 32
#  	 Train (with Adv) Loss:0.77 	 Train Acc:0.99
# 	 Discriminator Loss:0.69 	 Discriminator Acc:0.53
# 	 Val (with Target) Loss:0.11 	 Val (with Target) Acc:0.97
# Epoch: 33
#  	 Train (with Adv) Loss:0.77 	 Train Acc:0.99
# 	 Discriminator Loss:0.69 	 Discriminator Acc:0.53
# 	 Val (with Target) Loss:0.02 	 Val (with Target) Acc:0.99
# Epoch: 34
#  	 Train (with Adv) Loss:0.76 	 Train Acc:0.99
# 	 Discriminator Loss:0.69 	 Discriminator Acc:0.53
# 	 Val (with Target) Loss:0.03 	 Val (with Target) Acc:0.99
# Epoch: 35
#  	 Train (with Adv) Loss:0.77 	 Train Acc:0.99
# 	 Discriminator Loss:0.69 	 Discriminator Acc:0.53
# 	 Val (with Target) Loss:0.08 	 Val (with Target) Acc:0.98
# Epoch: 36
#  	 Train (with Adv) Loss:0.76 	 Train Acc:0.99
# 	 Discriminator Loss:0.69 	 Discriminator Acc:0.53
# 	 Val (with Target) Loss:0.12 	 Val (with Target) Acc:0.97
# Epoch: 37
#  	 Train (with Adv) Loss:0.75 	 Train Acc:0.99
# 	 Discriminator Loss:0.70 	 Discriminator Acc:0.52
# 	 Val (with Target) Loss:0.01 	 Val (with Target) Acc:1.00
# Epoch: 38
#  	 Train (with Adv) Loss:0.75 	 Train Acc:0.99
# 	 Discriminator Loss:0.70 	 Discriminator Acc:0.51
# 	 Val (with Target) Loss:0.06 	 Val (with Target) Acc:0.98
# Epoch: 39
#  	 Train (with Adv) Loss:0.76 	 Train Acc:0.99
# 	 Discriminator Loss:0.70 	 Discriminator Acc:0.51
# 	 Val (with Target) Loss:0.02 	 Val (with Target) Acc:1.00
# Epoch: 40
#  	 Train (with Adv) Loss:0.76 	 Train Acc:0.99
# 	 Discriminator Loss:0.69 	 Discriminator Acc:0.53
# 	 Val (with Target) Loss:0.11 	 Val (with Target) Acc:0.97
# Epoch: 41
#  	 Train (with Adv) Loss:0.77 	 Train Acc:0.99
# 	 Discriminator Loss:0.69 	 Discriminator Acc:0.53
# 	 Val (with Target) Loss:0.04 	 Val (with Target) Acc:0.99
# Epoch: 42
#  	 Train (with Adv) Loss:0.75 	 Train Acc:0.99
# 	 Discriminator Loss:0.70 	 Discriminator Acc:0.52
# 	 Val (with Target) Loss:0.02 	 Val (with Target) Acc:1.00
# Epoch: 43
#  	 Train (with Adv) Loss:0.76 	 Train Acc:0.99
# 	 Discriminator Loss:0.69 	 Discriminator Acc:0.54
# 	 Val (with Target) Loss:0.02 	 Val (with Target) Acc:1.00
# Epoch: 44
#  	 Train (with Adv) Loss:0.76 	 Train Acc:0.99
# 	 Discriminator Loss:0.69 	 Discriminator Acc:0.52
# 	 Val (with Target) Loss:0.04 	 Val (with Target) Acc:0.99
# Epoch: 45
#  	 Train (with Adv) Loss:0.77 	 Train Acc:0.99
# 	 Discriminator Loss:0.69 	 Discriminator Acc:0.54
# 	 Val (with Target) Loss:0.02 	 Val (with Target) Acc:1.00
# Epoch: 46
#  	 Train (with Adv) Loss:0.76 	 Train Acc:0.99
# 	 Discriminator Loss:0.69 	 Discriminator Acc:0.53
# 	 Val (with Target) Loss:0.02 	 Val (with Target) Acc:0.99
# Epoch: 47
#  	 Train (with Adv) Loss:0.75 	 Train Acc:0.99
# 	 Discriminator Loss:0.69 	 Discriminator Acc:0.53
# 	 Val (with Target) Loss:0.05 	 Val (with Target) Acc:0.99
# Epoch: 48
#  	 Train (with Adv) Loss:0.76 	 Train Acc:0.99
# 	 Discriminator Loss:0.69 	 Discriminator Acc:0.53
# 	 Val (with Target) Loss:0.02 	 Val (with Target) Acc:0.99
# Epoch: 49
#  	 Train (with Adv) Loss:0.75 	 Train Acc:0.99
# 	 Discriminator Loss:0.69 	 Discriminator Acc:0.52
# 	 Val (with Target) Loss:0.01 	 Val (with Target) Acc:1.00
# Epoch: 50
#  	 Train (with Adv) Loss:0.76 	 Train Acc:0.99
# 	 Discriminator Loss:0.69 	 Discriminator Acc:0.53
# 	 Val (with Target) Loss:0.02 	 Val (with Target) Acc:1.00
#
# Testing Accuracy on Previously Seen and Current Domains:
# Source Domain a:
# 	 Test (with Source) Loss:11.12 	 Test (with Source) Acc:0.50
# Target Domain b:
# 	 Test (with Target) Loss:0.03 	 Test (with Target) Acc:0.99
# Target Domain c:
# 	 Test (with Target) Loss:0.03 	 Test (with Target) Acc:0.99
# Target Domain d:
# 	 Test (with Target) Loss:0.03 	 Test (with Target) Acc:0.99

# %%
print(f'\nPhase 0 (Source Domain {source_domain})')
src_test_loss, src_test_acc = evaluate_src(encoder_tgt, classifier, phase='Test')
print(f'\t Test (with Source) Loss:{src_test_loss:0.2f} \t Test (with Source) Acc:{src_test_acc:0.2f}') 
for phase in range(len(target_domains)):
    if(phase == 0): # Domain A to B
        print(f'\nPhase {phase + 1} (Domain {source_domain} to Domain {target_domains[phase]})')
    else: # Domain B to C, and Domain C to D
        print(f'\nPhase {phase + 1} (Domain {target_domains[phase - 1]} to Domain {target_domains[phase]})')
    
    tgt_test_loss, tgt_test_acc = evaluate_tgt(encoder_tgt, classifier, test_dataloader_tgt[phase])
    print(f'\t Test (with Target) Loss:{tgt_test_loss:0.2f} \t Test (with Target) Acc:{tgt_test_acc:0.2f}')
# Out:
# Phase 0 (Source Domain a)
# 	 Test (with Source) Loss:11.12 	 Test (with Source) Acc:0.50
#
# Phase 1 (Domain a to Domain b)
# 	 Test (with Target) Loss:0.10 	 Test (with Target) Acc:0.99
#
# Phase 2 (Domain b to Domain c)
# 	 Test (with Target) Loss:0.99 	 Test (with Target) Acc:0.83
#
# Phase 3 (Domain c to Domain d)
# 	 Test (with Target) Loss:0.03 	 Test (with Target) Acc:0.99
